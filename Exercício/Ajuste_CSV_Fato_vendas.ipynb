# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/robso/Documents/GitHub/SCTEC/Semana_9/Dataset_schema/fato_vendas.csv')

# %%
df.head()
# Out:
#    venda_sk                          order_id  order_item_id  cliente_sk  \
# 0         1  00010242fe8c5a6d1ba2dd792cb16214              1       65558
# 1         2  00018f77f2f0320c557190d7a144bdd3              1       34266
# 2         3  000229ec398224ef6ca0657da4fc703e              1       34956
# 3         4  00024acbcdf0a6daa1e931b038114c75              1       51764
# 4         5  00042b26cf59d7ce69dfabb4e55b4fd9              1        7603
#
#    produto_sk  tempo_sk  valor_produto  valor_frete  valor_total
# 0       25866        64          58.90        13.29        72.19
# 1       27231       125         239.90        19.93       259.83
# 2       22625       222         199.00        17.87       216.87
# 3       15404         3          12.99        12.79        25.78
# 4        8863       512         199.90        18.14       218.04

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 110197 entries, 0 to 110196
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   venda_sk       110197 non-null  int64
#  1   order_id       110197 non-null  str
#  2   order_item_id  110197 non-null  int64
#  3   cliente_sk     110197 non-null  int64
#  4   produto_sk     110197 non-null  int64
#  5   tempo_sk       110197 non-null  int64
#  6   valor_produto  110197 non-null  float64
#  7   valor_frete    110197 non-null  float64
#  8   valor_total    110197 non-null  float64
# dtypes: float64(3), int64(5), str(1)
# memory usage: 7.6 MB

# %%
# ajustar as casas decimais dos valores da coluna 'valor_total'.
df['valor_total'] = df['valor_total'].round(2)

# %%
# Exportar o arquivo CSV ajustado
df.to_csv('C:/Users/robso/Documents/GitHub/SCTEC/Semana_9/Dataset_schema/fato_vendas_ajustado.csv', index=False)
